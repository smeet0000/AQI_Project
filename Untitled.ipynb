# %%
pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in C:\Users\SMIT\anaconda3\Lib\site-packages (9.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector as mc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Problem Statement 2: Data Extraction from MySQL to Python
# •	Fetch full AQI dataset from MySQL using Python
# •	Verify row counts between MySQL and Python
# •	Identify inconsistencies between stored and fetched data

# %%
conn = mc.connect(
    host="localhost",       # your server
    user="root",            # your MySQL username
    password="smit0987",
    database="aqi"
)
conn

# %%
if conn.is_connected():
    print("connected mysql successfully")
# Out:
# connected mysql successfully

# %%
query = "select * from aqi_raw"
df = pd.read_sql(query,conn)
df
# Out:
# C:\Users\SMIT\AppData\Local\Temp\ipykernel_13348\1328774007.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query,conn)
#           id           City        Date  PM2_5   PM10     NO    NO2    NOx  \
# 0          1      Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15
# 1          2      Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46
# 2          3      Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70
# 3          4      Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97
# 4          5      Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76
# ...      ...            ...         ...    ...    ...    ...    ...    ...
# 29526  29527  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54
# 29527  29528  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53
# 29528  29529  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33
# 29529  29530  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80
# 29530  29531  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05
#
#          NH3     CO    SO2      O3  Benzene  Toluene  Xylene   AQI  \
# 0        NaN   0.92  27.64  133.36     0.00     0.02    0.00   NaN
# 1        NaN   0.97  24.55   34.06     3.68     5.50    3.77   NaN
# 2        NaN  17.40  29.07   30.70     6.80    16.40    2.25   NaN
# 3        NaN   1.70  18.59   36.08     4.43    10.14    1.00   NaN
# 4        NaN  22.10  39.33   39.31     7.01    18.89    2.78   NaN
# ...      ...    ...    ...     ...      ...      ...     ...   ...
# 29526  12.47   0.47   8.55   23.30     2.24    12.07    0.73  41.0
# 29527  11.99   0.52  12.72   30.14     0.74     2.21    0.38  70.0
# 29528  10.71   0.48   8.42   30.96     0.01     0.01    0.00  68.0
# 29529  10.03   0.52   9.84   28.30     0.00     0.00    0.00  54.0
# 29530   5.20   0.59   2.10   17.05      NaN      NaN     NaN  50.0
#
#          AQI_Bucket
# 0
# 1
# 2
# 3
# 4
# ...             ...
# 29526          Good
# 29527  Satisfactory
# 29528  Satisfactory
# 29529  Satisfactory
# 29530          Good
#
# [29531 rows x 17 columns]

# %%
df.shape
# Out:
# (29531, 17)

# %% [markdown]
# ### Both has same amount of rows and columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          29531 non-null  int64
#  1   City        29531 non-null  object
#  2   Date        29531 non-null  object
#  3   PM2_5       24933 non-null  float64
#  4   PM10        18391 non-null  float64
#  5   NO          25949 non-null  float64
#  6   NO2         25946 non-null  float64
#  7   NOx         25346 non-null  float64
#  8   NH3         19203 non-null  float64
#  9   CO          27472 non-null  float64
#  10  SO2         25677 non-null  float64
#  11  O3          25509 non-null  float64
#  12  Benzene     23908 non-null  float64
#  13  Toluene     21490 non-null  float64
#  14  Xylene      11422 non-null  float64
#  15  AQI         24850 non-null  float64
#  16  AQI_Bucket  29531 non-null  object
# dtypes: float64(13), int64(1), object(3)
# memory usage: 3.8+ MB

# %%
cursor = conn.cursor()
cursor.execute("SELECT COUNT(*) FROM aqi_raw")
mysql_count = cursor.fetchone()[0]

python_count = len(df)

if mysql_count == python_count:
    print("Row count matches")
else:
    print("Row count mismatch")

print("MySQL:", mysql_count, "Python:", python_count)
# Out:
# Row count matches
# MySQL: 29531 Python: 29531

# %%
df.isnull().sum()
# Out:
# id                0
# City              0
# Date              0
# PM2_5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket        0
# dtype: int64

# %%
df.duplicated(['Date','City']).sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Problem Statement 3: Data Cleaning & Standardization in Python
# Objective: Improve data quality for accurate analysis.
# •	Handle missing pollutant values
# •	Standardize city names and AQI buckets
# •	Remove or correct invalid pollutant readings
# •	Create derived columns (monthly AQI, pollutant ratios)

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("city_day.csv")

# %%
df.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %% [markdown]
# ## Instead of taking mean use meadian to prevent outlier(prevent uncertanity in data)

# %%
pollutant_cols = ['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3',
                  'Benzene','Toluene','Xylene','AQI']

for col in pollutant_cols:
    df[col] = df[col].fillna(df.groupby('City')[col].transform('median'))
    df[col] = df[col].fillna(df[col].median())

# %%
df.isnull().sum()
# Out:
# City             0
# Date             0
# PM2.5            0
# PM10             0
# NO               0
# NO2              0
# NOx              0
# NH3              0
# CO               0
# SO2              0
# O3               0
# Benzene          0
# Toluene          0
# Xylene           0
# AQI              0
# AQI_Bucket    4681
# dtype: int64

# %%
df.columns = df.columns.str.strip()

# %%
df.isnull().sum()
# Out:
# City             0
# Date             0
# PM2.5            0
# PM10             0
# NO               0
# NO2              0
# NOx              0
# NH3              0
# CO               0
# SO2              0
# O3               0
# Benzene          0
# Toluene          0
# Xylene           0
# AQI              0
# AQI_Bucket    4681
# dtype: int64

# %%
df
# Out:
#                 City        Date  PM2.5    PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01  58.37  107.96   0.92  18.22  17.15  14.50
# 1          Ahmedabad  2015-01-02  58.37  107.96   0.97  15.69  16.46  14.50
# 2          Ahmedabad  2015-01-03  58.37  107.96  17.40  19.30  29.70  14.50
# 3          Ahmedabad  2015-01-04  58.37  107.96   1.70  18.48  17.97  14.50
# 4          Ahmedabad  2015-01-05  58.37  107.96  22.10  21.42  37.76  14.50
# ...              ...         ...    ...     ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02   50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38   74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91   65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64   49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00   66.00   0.40  26.85  14.05   5.20
#
#           CO    SO2      O3  Benzene  Toluene  Xylene    AQI    AQI_Bucket
# 0       0.92  27.64  133.36     0.00     0.02    0.00  384.5           NaN
# 1       0.97  24.55   34.06     3.68     5.50    3.77  384.5           NaN
# 2      17.40  29.07   30.70     6.80    16.40    2.25  384.5           NaN
# 3       1.70  18.59   36.08     4.43    10.14    1.00  384.5           NaN
# 4      22.10  39.33   39.31     7.01    18.89    2.78  384.5           NaN
# ...      ...    ...     ...      ...      ...     ...    ...           ...
# 29526   0.47   8.55   23.30     2.24    12.07    0.73   41.0          Good
# 29527   0.52  12.72   30.14     0.74     2.21    0.38   70.0  Satisfactory
# 29528   0.48   8.42   30.96     0.01     0.01    0.00   68.0  Satisfactory
# 29529   0.52   9.84   28.30     0.00     0.00    0.00   54.0  Satisfactory
# 29530   0.59   2.10   17.05     4.04     8.00    2.18   50.0          Good
#
# [29531 rows x 16 columns]

# %%
conditions = [
    (df['AQI'] <= 50),
    (df['AQI'] <= 100),
    (df['AQI'] <= 200),
    (df['AQI'] <= 300),
    (df['AQI'] <= 400),
    (df['AQI'] > 400)
]

choices = ['Good', 'Satisfactory', 'Moderate', 'Poor', 'Very Poor', 'Severe']

df['AQI_Bucket'] = np.select(conditions, choices, default=df['AQI_Bucket'])

# %%
df['City'] = df['City'].str.strip().str.title()

# %%
print(df['City'].unique())
print(df['AQI_Bucket'].unique())
# Out:
# ['Ahmedabad' 'Aizawl' 'Amaravati' 'Amritsar' 'Bengaluru' 'Bhopal'
#  'Brajrajnagar' 'Chandigarh' 'Chennai' 'Coimbatore' 'Delhi' 'Ernakulam'
#  'Gurugram' 'Guwahati' 'Hyderabad' 'Jaipur' 'Jorapokhar' 'Kochi' 'Kolkata'
#  'Lucknow' 'Mumbai' 'Patna' 'Shillong' 'Talcher' 'Thiruvananthapuram'
#  'Visakhapatnam']
# ['Very Poor' 'Poor' 'Severe' 'Moderate' 'Satisfactory' 'Good']

# %%
df.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  29531.000000  29531.000000  29531.000000  29531.000000  29531.000000
# mean      64.495018    111.529814     17.586426     28.038496     31.738348
# std       60.418818     75.030435     21.513692     23.404976     29.538093
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       28.080000     63.775000      6.100000     12.080000     14.495000
# 50%       48.170000    100.685000     10.580000     21.460000     24.290000
# 75%       76.345000    125.615000     22.220000     36.650000     39.510000
# max      949.990000   1000.000000    390.680000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  29531.000000  29531.000000  29531.000000  29531.000000  29531.000000
# mean      21.785599      2.469716     15.120249     33.794051      2.879523
# std       21.530224      7.014473     17.676906     20.445550     14.257731
# min        0.010000      0.000000      0.010000      0.010000      0.000000
# 25%       10.770000      0.510000      6.050000     19.960000      0.180000
# 50%       14.500000      0.900000      9.900000     29.620000      1.020000
# 75%       27.070000      1.500000     15.600000     43.025000      2.750000
# max      352.890000    175.810000    193.860000    257.730000    455.030000
#
#             Toluene        Xylene           AQI
# count  29531.000000  29531.000000  29531.000000
# mean       7.250242      1.968859    165.369578
# std       17.424784      4.077188    135.315410
# min        0.000000      0.000000     13.000000
# 25%        0.680000      0.780000     86.000000
# 50%        2.650000      1.130000    117.000000
# 75%        6.720000      1.600000    208.000000
# max      454.850000    170.370000   2049.000000

# %%
df["Date"] = pd.to_datetime(df["Date"], format="%Y-%m-%d")

# %% [markdown]
# ### Create Derived Column

# %%
df['Month'] = df['Date'].dt.to_period('M')

# %%
df.dtypes
# Out:
# City                  object
# Date          datetime64[ns]
# PM2.5                float64
# PM10                 float64
# NO                   float64
# NO2                  float64
# NOx                  float64
# NH3                  float64
# CO                   float64
# SO2                  float64
# O3                   float64
# Benzene              float64
# Toluene              float64
# Xylene               float64
# AQI                  float64
# AQI_Bucket            object
# Month              period[M]
# dtype: object

# %%
df['Month'] = df['Date'].dt.month_name()
df['Year'] = df['Date'].dt.year

# %%
df
# Out:
#                 City       Date  PM2.5    PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad 2015-01-01  58.37  107.96   0.92  18.22  17.15  14.50
# 1          Ahmedabad 2015-01-02  58.37  107.96   0.97  15.69  16.46  14.50
# 2          Ahmedabad 2015-01-03  58.37  107.96  17.40  19.30  29.70  14.50
# 3          Ahmedabad 2015-01-04  58.37  107.96   1.70  18.48  17.97  14.50
# 4          Ahmedabad 2015-01-05  58.37  107.96  22.10  21.42  37.76  14.50
# ...              ...        ...    ...     ...    ...    ...    ...    ...
# 29526  Visakhapatnam 2020-06-27  15.02   50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam 2020-06-28  24.38   74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam 2020-06-29  22.91   65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam 2020-06-30  16.64   49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam 2020-07-01  15.00   66.00   0.40  26.85  14.05   5.20
#
#           CO    SO2      O3  Benzene  Toluene  Xylene    AQI    AQI_Bucket  \
# 0       0.92  27.64  133.36     0.00     0.02    0.00  384.5     Very Poor
# 1       0.97  24.55   34.06     3.68     5.50    3.77  384.5     Very Poor
# 2      17.40  29.07   30.70     6.80    16.40    2.25  384.5     Very Poor
# 3       1.70  18.59   36.08     4.43    10.14    1.00  384.5     Very Poor
# 4      22.10  39.33   39.31     7.01    18.89    2.78  384.5     Very Poor
# ...      ...    ...     ...      ...      ...     ...    ...           ...
# 29526   0.47   8.55   23.30     2.24    12.07    0.73   41.0          Good
# 29527   0.52  12.72   30.14     0.74     2.21    0.38   70.0  Satisfactory
# 29528   0.48   8.42   30.96     0.01     0.01    0.00   68.0  Satisfactory
# 29529   0.52   9.84   28.30     0.00     0.00    0.00   54.0  Satisfactory
# 29530   0.59   2.10   17.05     4.04     8.00    2.18   50.0          Good
#
#          Month  Year
# 0      January  2015
# 1      January  2015
# 2      January  2015
# 3      January  2015
# 4      January  2015
# ...        ...   ...
# 29526     June  2020
# 29527     June  2020
# 29528     June  2020
# 29529     June  2020
# 29530     July  2020
#
# [29531 rows x 18 columns]

# %%
df["Monthly_AQI"] = df.groupby(["City","Year","Month"])["AQI"].transform("mean").round(2)
df[['City','Year','Month','Monthly_AQI']]
# Out:
#                 City  Year    Month  Monthly_AQI
# 0          Ahmedabad  2015  January       381.19
# 1          Ahmedabad  2015  January       381.19
# 2          Ahmedabad  2015  January       381.19
# 3          Ahmedabad  2015  January       381.19
# 4          Ahmedabad  2015  January       381.19
# ...              ...   ...      ...          ...
# 29526  Visakhapatnam  2020     June        82.20
# 29527  Visakhapatnam  2020     June        82.20
# 29528  Visakhapatnam  2020     June        82.20
# 29529  Visakhapatnam  2020     June        82.20
# 29530  Visakhapatnam  2020     July        50.00
#
# [29531 rows x 4 columns]

# %%
df['PM_Ratio'] = np.where(df['PM10'] == 0, 0, df['PM2.5'] / df['PM10'])
df['PM_Ratio']
# Out:
# 0        0.540663
# 1        0.540663
# 2        0.540663
# 3        0.540663
# 4        0.540663
#            ...
# 29526    0.294857
# 29527    0.329059
# 29528    0.348547
# 29529    0.333000
# 29530    0.227273
# Name: PM_Ratio, Length: 29531, dtype: float64

# %% [markdown]
# #### 1. PM Ratio ($PM_{2.5} / PM_{10}$)
# * *Purpose:* Measures the proportion of "Fine" vs. "Coarse" particles.
# * *Interpretation:* * *High Ratio (> 0.6):* Indicates *Combustion sources* (vehicle exhaust, biomass burning, industrial smoke). These fine particles are more hazardous as they penetrate deeper into the respiratory system.
#     * *Low Ratio (< 0.4):* Indicates *Mechanical sources* (road dust, construction, or wind-blown soil/sand).

# %%
df['NO2_NOx_Ratio'] = np.where(df['NOx'] == 0, 0, df['NO2'] / df['NOx']) 
df['NO2_NOx_Ratio']
# Out:
# 0        1.062391
# 1        0.953220
# 2        0.649832
# 3        1.028381
# 4        0.567267
#            ...
# 29526    1.282497
# 29527    1.576528
# 29528    1.611020
# 29529    1.556383
# 29530    1.911032
# Name: NO2_NOx_Ratio, Length: 29531, dtype: float64

# %% [markdown]
# #### 2. Nitrogen Ratio ($NO_2 / NO_x$)
# * *Purpose:* Tracks the "age" of traffic pollution and secondary smog formation.
# * *Interpretation:*
#     * *High Ratio (> 0.7):* Indicates *Stale/Processed Urban Air*. High $NO_2$ suggests significant photochemical activity (the primary $NO$ has had time to oxidize into $NO_2$).
#     * *Low Ratio (< 0.3):* Indicates *Fresh Emissions*. This is common very close to tailpipes or industrial stacks before the gasses have reacted with the atmosphere.

# %%
df['CO_O3_Ratio'] = np.where(df['O3'] == 0, 0, df['CO'] / df['O3'])
df['CO_O3_Ratio']
# Out:
# 0        0.006899
# 1        0.028479
# 2        0.566775
# 3        0.047118
# 4        0.562198
#            ...
# 29526    0.020172
# 29527    0.017253
# 29528    0.015504
# 29529    0.018375
# 29530    0.034604
# Name: CO_O3_Ratio, Length: 29531, dtype: float64

# %% [markdown]
# #### 3. Combustion Balance ($CO / O_3$)
# * *Purpose:* Balances primary emissions ($CO$) against secondary photochemical pollutants ($O_3$).
# * *Interpretation:*
#     * *High Ratio (> 2.0):* Indicates *Incomplete Combustion*. Suggests heavy traffic or industrial burning in stagnant air where Ozone formation is inhibited.
#     * *Low Ratio (< 1.0):* Indicates *Ozone Dominance*. Typically occurs on hot, sunny days; suggests high levels of photochemical smog.

# %%
df['SO2_NO2_Ratio'] = np.where(df['NO2'] == 0, 0, df['SO2'] / df['NO2'])
df['SO2_NO2_Ratio']
# Out:
# 0        1.517014
# 1        1.564691
# 2        1.506218
# 3        1.005952
# 4        1.836134
#            ...
# 29526    0.341181
# 29527    0.488104
# 29528    0.285134
# 29529    0.336295
# 29530    0.078212
# Name: SO2_NO2_Ratio, Length: 29531, dtype: float64

# %% [markdown]
# #### 4. Source Identifier ($SO_2 / NO_2$)
# * *Purpose:* Distinguishes between industrial and vehicular fuel types.
# * *Interpretation:*
#     * *High Ratio (> 1.0):* Indicates *Industrial/Coal dominance*. $SO_2$ is a classic marker for coal-fired power plants and heavy manufacturing.
#     * *Low Ratio (< 0.5):* Indicates *Vehicle dominance*. Modern urban centers are usually dominated by $NO_2$ from gasoline and diesel engines

# %% [markdown]
# ### Problem statement 4

# %%
from sqlalchemy import create_engine

engine = create_engine("mysql+mysqlconnector://root:smit0987@localhost/aqi")

df.to_sql('aqi_cleaned', con=engine, if_exists='replace', index=False)

print("Upload successful using mysql-connector!")
# Out:
# Upload successful using mysql-connector!

# %% [markdown]
# ### Problem statement 6

# %%
from sqlalchemy import create_engine

engine = create_engine("mysql+mysqlconnector://root:smit0987@localhost/aqi")

df_clean = pd.read_sql("SELECT * FROM aqi_cleaned", engine)

# %%
df_clean
# Out:
#                 City       Date  PM2.5    PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad 2015-01-01  58.37  107.96   0.92  18.22  17.15  14.50
# 1          Ahmedabad 2015-01-02  58.37  107.96   0.97  15.69  16.46  14.50
# 2          Ahmedabad 2015-01-03  58.37  107.96  17.40  19.30  29.70  14.50
# 3          Ahmedabad 2015-01-04  58.37  107.96   1.70  18.48  17.97  14.50
# 4          Ahmedabad 2015-01-05  58.37  107.96  22.10  21.42  37.76  14.50
# ...              ...        ...    ...     ...    ...    ...    ...    ...
# 29526  Visakhapatnam 2020-06-27  15.02   50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam 2020-06-28  24.38   74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam 2020-06-29  22.91   65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam 2020-06-30  16.64   49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam 2020-07-01  15.00   66.00   0.40  26.85  14.05   5.20
#
#           CO    SO2  ...    AQI    AQI_Bucket  Month  Year  Monthly_AQI  \
# 0       0.92  27.64  ...  384.5     Very Poor      1  2015       381.19
# 1       0.97  24.55  ...  384.5     Very Poor      1  2015       381.19
# 2      17.40  29.07  ...  384.5     Very Poor      1  2015       381.19
# 3       1.70  18.59  ...  384.5     Very Poor      1  2015       381.19
# 4      22.10  39.33  ...  384.5     Very Poor      1  2015       381.19
# ...      ...    ...  ...    ...           ...    ...   ...          ...
# 29526   0.47   8.55  ...   41.0          Good      6  2020        82.20
# 29527   0.52  12.72  ...   70.0  Satisfactory      6  2020        82.20
# 29528   0.48   8.42  ...   68.0  Satisfactory      6  2020        82.20
# 29529   0.52   9.84  ...   54.0  Satisfactory      6  2020        82.20
# 29530   0.59   2.10  ...   50.0          Good      7  2020        50.00
#
#       PM_Ratio  NO2_NOx_Ratio  CO_O3_Ratio  SO2_NO2_Ratio  Month_num
# 0       0.5407         1.0624       0.0069         1.5170          1
# 1       0.5407         0.9532       0.0285         1.5647          1
# 2       0.5407         0.6498       0.5668         1.5062          1
# 3       0.5407         1.0284       0.0471         1.0060          1
# 4       0.5407         0.5673       0.5622         1.8361          1
# ...        ...            ...          ...            ...        ...
# 29526   0.2949         1.2825       0.0202         0.3412          6
# 29527   0.3291         1.5765       0.0173         0.4881          6
# 29528   0.3485         1.6110       0.0155         0.2851          6
# 29529   0.3330         1.5564       0.0184         0.3363          6
# 29530   0.2273         1.9110       0.0346         0.0782          7
#
# [29531 rows x 24 columns]

# %%
df_clean['Month'] = df_clean['Date'].dt.month
df_clean[['Year','Month','Month_name']]
# Out:
#        Year  Month Month_name
# 0      2015      1    January
# 1      2015      1    January
# 2      2015      1    January
# 3      2015      1    January
# 4      2015      1    January
# ...     ...    ...        ...
# 29526  2020      6       June
# 29527  2020      6       June
# 29528  2020      6       June
# 29529  2020      6       June
# 29530  2020      7       July
#
# [29531 rows x 3 columns]

# %%
df_clean['Month_name'] = df_clean['Date'].dt.month_name()

# %% [markdown]
# # AQI Trend Over Time

# %%
monthly = df_clean.groupby(['Year','Month'])['AQI'].mean().reset_index()
monthly['Period'] = pd.to_datetime(
    monthly[['Year','Month']].assign(day=1)
)
plt.figure(figsize=(12,5))
plt.plot(monthly['Period'], monthly['AQI'], color='steelblue', lw=3)
plt.fill_between(monthly['Period'], monthly['AQI'], alpha=0.15)
plt.title("National Average AQI Trend (2015–2020)")
plt.xlabel("Date") 
plt.ylabel("Average AQI")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Pollutant Contribution By Country

# %%
top_cities = df_clean.groupby('City')['AQI'].mean().sort_values(ascending=False)
colors = ['#d73027' if v > 200 else '#fc8d59'
          if v > 100 else '#91cf60' for v in top_cities]
plt.figure(figsize = (14,6))
plt.bar(top_cities.index, top_cities.values, color=colors)
plt.title("Top Polluted Cities - Higher AQI means worse air quality")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # 3. AQI Bucket Distribution

# %%
bucket_counts = df_clean['AQI_Bucket'].value_counts()
colors = [
    '#2E7D32' if b == 'Good' else          # Dark Green
    '#66BB6A' if b == 'Satisfactory' else  # Medium Green
    '#FBC02D' if b == 'Moderate' else      # Dark Yellow
    '#EF6C00' if b == 'Poor' else          # Dark Orange
    '#C62828' if b == 'Very Poor' else     # Dark Red
    '#6A1B9A'                              # Deep Purple (Severe)
    for b in bucket_counts.index
]
plt.figure(figsize = (14,6))
plt.pie(bucket_counts, labels=bucket_counts.index, autopct='%1.1f%%', colors=colors)
plt.legend(bucket_counts.index, title="AQI Categories", loc="center left", bbox_to_anchor=(1.2, 0.5))
plt.title("AQI Bucket Distribution - Overall air quality condition")
plt.show()

# %% [markdown]
# # 4. Compare raw vs cleaned AQI behavior

# %%
from sqlalchemy import create_engine

engine = create_engine("mysql+mysqlconnector://root:smit0987@localhost/aqi")

df_raw = pd.read_sql("SELECT * FROM aqi_raw", engine)
df_cleaned = pd.read_sql("SELECT * FROM aqi_cleaned", engine)

# %%
plt.figure(figsize=(10,5))

plt.hist(df_raw['AQI'], bins=50, alpha=0.5, label='Raw AQI')
plt.hist(df_cleaned['AQI'], bins=50, alpha=0.5, label='Cleaned AQI')

plt.title("Raw vs Cleaned AQI Distribution")
plt.xlabel("AQI")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cols = ['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','AQI']

corr = df_clean[cols].corr()

plt.figure(figsize=(10,8))

sns.heatmap(corr, 
            annot=True,        # show values
            fmt=".2f", 
            cmap="RdYlGn_r",   # color theme
            linewidths=0.5)

plt.title("Correlation Heatmap of Pollutants")
plt.show()

# %%
pollutants = ['PM2.5','PM10','NO2','SO2','CO','O3']
pollution_avg = df_clean[pollutants].mean()

plt.figure()
plt.bar(pollution_avg.index, pollution_avg.values, color='orange')
plt.title("Pollutant Contribution - Identifies major pollutants")
plt.show()

# %%
plt.scatter(df_cleaned['PM10'], df_cleaned['AQI'])
plt.xlabel("PM10")
plt.ylabel("AQI")
plt.title("PM10 vs AQI")
plt.show()
